# %%
import pandas as pd
df = pd.read_csv('advertising_sales_dataset.csv')

# %%
df
# Out:
#       Instagram  Facebook  YouTube  Twitter  Telegram  WhatsApp  TikTok  \
# 0            48        44       53       12        74        27      14
# 1            47        44       52       13        40        36      58
# 2            79        40       73       59        53        34      37
# 3            72        42       41       12        55        17      45
# 4            87        79       32       32        70        25      54
# ...         ...       ...      ...      ...       ...       ...     ...
# 7693         91        69       38       32        47        19      55
# 7694         77        56       24       67        74        14      50
# 7695         52        78       56       42        61        22      65
# 7696         23        21       69       48        15        35      10
# 7697         75        69       73       29        53        37      10
#
#       Radio  TV  Newspaper  Website  Sales
# 0         8   2         24       15     30
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Instagram  Facebook  YouTube  Twitter  Telegram  WhatsApp  TikTok  \
# 0            48        44       53       12        74        27      14
# 1            47        44       52       13        40        36      58
# 2            79        40       73       59        53        34      37
# 3            72        42       41       12        55        17      45
# 4            87        79       32       32        70        25      54
# ...         ...       ...      ...      ...       ...       ...     ...
# 7693         91        69       38       32        47        19      55
# 7694         77        56       24       67        74        14      50
# 7695         52        78       56       42        61        22      65
# 7696         23        21       69       48        15        35      10
# 7697         75        69       73       29        53        37      10
#
#       Radio  TV  Newspaper  Website  Sales
# ...

# %%
df.isnull().sum()
# Out:
# Instagram    0
# Facebook     0
# YouTube      0
# Twitter      0
# Telegram     0
# WhatsApp     0
# TikTok       0
# Radio        0
# TV           0
# Newspaper    0
# Website      0
# Sales        0
# dtype: int64

# %%
df.describe()
# Out:
#          Instagram     Facebook      YouTube      Twitter     Telegram  \
# count  7698.000000  7698.000000  7698.000000  7698.000000  7698.000000
# mean     58.332814    56.797870    39.998961    39.872175    44.459340
# std      22.338274    21.412689    22.792111    22.865867    20.213566
# min      20.000000    20.000000     1.000000     1.000000    10.000000
# 25%      39.000000    38.000000    20.000000    20.000000    27.000000
# 50%      58.500000    57.000000    40.000000    40.000000    45.000000
# 75%      78.000000    75.000000    60.000000    60.000000    62.000000
# max      96.000000    94.000000    79.000000    79.000000    79.000000
#
#           WhatsApp       TikTok        Radio           TV    Newspaper  \
# count  7698.000000  7698.000000  7698.000000  7698.000000  7698.000000
# mean     20.104313    44.433619    25.279813    25.088335    24.949337
# std      11.221657    20.214250    14.086313    14.260817    14.242906
# ...

# %%
cor = df.corr()
cor
# Out:
#            Instagram  Facebook   YouTube   Twitter  Telegram  WhatsApp  \
# Instagram   1.000000  0.021300  0.016361 -0.004946  0.000404 -0.008409
# Facebook    0.021300  1.000000  0.015022 -0.012523 -0.009483 -0.006049
# YouTube     0.016361  0.015022  1.000000 -0.015635  0.009797 -0.015753
# Twitter    -0.004946 -0.012523 -0.015635  1.000000 -0.015246 -0.031001
# Telegram    0.000404 -0.009483  0.009797 -0.015246  1.000000 -0.002560
# WhatsApp   -0.008409 -0.006049 -0.015753 -0.031001 -0.002560  1.000000
# TikTok      0.005368 -0.011806 -0.009736 -0.023296  0.025470  0.005781
# Radio      -0.020527  0.011174  0.003449  0.002322  0.007967 -0.001684
# TV         -0.005408  0.023851  0.014587 -0.000141 -0.005262  0.010238
# Newspaper  -0.012307 -0.011966 -0.011857  0.005001  0.014766  0.014832
# Website    -0.019268  0.017267  0.014898  0.005367 -0.007755  0.001633
# Sales      -0.025489  0.000348  0.005443 -0.004492  0.000086  0.021566
#
# ...

# %%
df = pd.read_csv('DataSet.csv')

# %%
df
# Out:
#                                                    title  \
# 0                                       Marketing Intern
# 1              Customer Service - Cloud Video Production
# 2                Commissioning Machinery Assistant (CMA)
# 3                      Account Executive - Washington DC
# 4                                    Bill Review Manager
# ...                                                  ...
# 17875                   Account Director - Distribution
# 17876                                 Payroll Accountant
# 17877  Project Cost Control Staff Engineer - Cost Con...
# 17878                                   Graphic Designer
# 17879                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# 2             US, IA, Wever          NaN          NaN
# 3        US, DC, Washington        Sales          NaN
# ...

# %%
df['fraudulent'].unique()
# Out:
# array(['f', 't'], dtype=object)

# %%
df[df['fraudulent']=='t']
# Out:
#                                             title  \
# 98                                IC&E Technician
# 144                                  Forward Cap.
# 173             Technician Instrument & Controls
# 180                               Sales Executive
# 215                       IC&E Technician Mt Poso
# ...                                           ...
# 17827  Student Positions Part-Time and Full-Time.
# 17828                             Sales Associate
# 17829                           Android Developer
# 17830                              Payroll Clerk
# 17831                             Furniture mover
#
#                                  location            department  salary_range  \
# 98                      US, , Stocton, CA          Oil & Energy  95000-115000
# 144                                   NaN                   NaN           NaN
# 173                                    US  Power Plant & Energy           NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                17880 non-null  object
#  1   location             17534 non-null  object
#  2   department           6333 non-null   object
#  3   salary_range         2868 non-null   object
#  4   company_profile      14572 non-null  object
#  5   description          17880 non-null  object
#  6   requirements         15191 non-null  object
#  7   benefits             10684 non-null  object
#  8   telecommuting        17880 non-null  object
#  9   has_company_logo     17880 non-null  object
#  10  has_questions        17880 non-null  object
#  11  employment_type      14409 non-null  object
#  12  required_experience  10830 non-null  object
#  13  required_education   9775 non-null   object
#  14  industry             12977 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                0
# requirements            2689
# benefits                7196
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# in_balanced_dataset        0
# dtype: int64

# %%
dk = df.drop(columns=['salary_range','department','benefits','required_experience','required_education','function'])

# %%
dk.isnull().sum()
# Out:
# title                     0
# location                346
# company_profile        3308
# description               0
# requirements           2689
# telecommuting             0
# has_company_logo          0
# has_questions             0
# employment_type        3471
# industry               4903
# fraudulent                0
# in_balanced_dataset       0
# dtype: int64

# %%
dk = dk.dropna()

# %%
dk.isnull().sum()
# Out:
# title                  0
# location               0
# company_profile        0
# description            0
# requirements           0
# telecommuting          0
# has_company_logo       0
# has_questions          0
# employment_type        0
# industry               0
# fraudulent             0
# in_balanced_dataset    0
# dtype: int64

# %%
dk.shape
# Out:
# (9706, 12)

# %%
dk[dk['fraudulent'] == 't']
# Out:
#                                         title  \
# 98                            IC&E Technician
# 173         Technician Instrument & Controls
# 215                   IC&E Technician Mt Poso
# 357                 Financing Auto(car) sales
# 573        Senior Engineering Product Manager
# ...                                       ...
# 17776               Administrative Assistant
# 17793             Project Controls Technician
# 17797  Agency Sales Managers $150-$175,000/yr
# 17811  Agency Sales Managers $150-$175,000/yr
# 17813         Customer Service Representative
#
#                                  location  \
# 98                      US, , Stocton, CA
# 173                                    US
# 215    US, CA, Bakersfield, CA / Mt. Poso
# 357                    US, IL, hazelcrest
# 573                      US, CA, San Jose
# ...                                   ...
# 17776                     US, TX, Houston
# 17793                 US, CA, Bakersfield
# ...

# %%
dk.to_csv("projekportoclean.csv", index=False)

# %%
dk.to_excel('projekportoclean.xlsx',index=False)

# %%
dm = pd.read_excel('projekporto.xlsx')

# %%
dm
# Out:
#                                           title               location  \
# 0     Customer Service - Cloud Video Production         NZ, , Auckland
# 1             Account Executive - Washington DC     US, DC, Washington
# 2                           Bill Review Manager     US, FL, Fort Worth
# 3                         Head of Content (m/f)         DE, BE, Berlin
# 4                                    HP BSM SME      US, FL, Pensacola
# ...                                         ...                    ...
# 9701                         Water Truck Driver     US, PA, Waynesburg
# 9702                            Product Manager  US, CA, San Francisco
# 9703           Account Director - Distribution         CA, ON, Toronto
# 9704                         Payroll Accountant   US, PA, Philadelphia
# 9705                 Web Application Developers      NZ, N, Wellington
#
#                                         company_profile  \
# 0     90 Seconds, the worlds Cloud Video Production ...
# ...

# %%
dm["description"] = dm["description"].str.replace("_\n_x000D_\n", "")
dm['company_profile'] = dm['company_profile'].str.replace("_\n_x000D_\n", "")
dm['requirements'] = dm['requirements'].str.replace("_\n_x000D_\n", "")

# %%
dm
# Out:
#                                           title               location  \
# 0     Customer Service - Cloud Video Production         NZ, , Auckland
# 1             Account Executive - Washington DC     US, DC, Washington
# 2                           Bill Review Manager     US, FL, Fort Worth
# 3                         Head of Content (m/f)         DE, BE, Berlin
# 4                                    HP BSM SME      US, FL, Pensacola
# ...                                         ...                    ...
# 9701                         Water Truck Driver     US, PA, Waynesburg
# 9702                            Product Manager  US, CA, San Francisco
# 9703           Account Director - Distribution         CA, ON, Toronto
# 9704                         Payroll Accountant   US, PA, Philadelphia
# 9705                 Web Application Developers      NZ, N, Wellington
#
#                                         company_profile  \
# 0     90 Seconds, the worlds Cloud Video Production ...
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %%
example = dm['requirements'][0]
print(example)
# Out:
# What we expect from you:_x000D_
# Your key responsibility will be to communicate with the client, 90 Seconds team and freelance community throughout the video production process including, shoot planning, securing freelance talent, managing workflow and the online production management system.  The aim is to manage each video project effectively so that we produce great videos that our clients love._x000D_
# Key attributes_x000D_x000D_
# ...
